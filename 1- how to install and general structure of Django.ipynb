# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Requirements

# %% [markdown]
# 1- python
# 2- python ide (pycharm - vscod - ... )

# %% [markdown]
# # Setup

# %% [markdown]
# ## Getting started with Django
#
# 1. Django Project:
#     https://www.djangoproject.com
# 2. Django documentation:
#     https://docs.djangoproject.com/en/1.11/
# 3. How to get Django:
#     https://www.djangoproject.com/download/
#
#
# ## Install Django
# >pip install Django

# %% [markdown]
# ## Verifying

# %%
import django
print(django.get_version())

# %% [markdown]
# # Django Architecture

# %% [markdown]
# ![image.png](attachment:image.png)
